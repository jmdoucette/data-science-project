# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
client_id="80889fe3c12c4fb49f18fef114f6bd7b"
client_secret = "c870b38402ac4981b56e181ff04c411f"
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
ids=pd.read_csv("/Users/jamesdoucette/Desktop/Schoolwork/data-science-project/id.csv")

# %%
test=ids.head(100)

# %%
def get_row(id):
    track=sp.track(id)
    features=sp.audio_features(id)
    
    name = track['name']
    album = track['album']['name']
    artist = track['album']['artists'][0]['name']
    release_date = track['album']['release_date']
    length = track['duration_ms']
    popularity = track['popularity']
    
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']
    
    return [id, name, album, artist, release_date, length, popularity, danceability, acousticness, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]

# %%
df=pd.DataFrame(columns=['id','name','album','artist','release_date','length','popularity','danceability','acousticness','energy','instrumentalness','liveness','loudness','speechiness','tempo','time_signature'])

# %%
testdf=df.copy()

# %%
start=time.time()
for id in ids['id']:
    df.loc[len(df)]=get_row(id)
end=time.time()
print(end-start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-3ee9ae56198d> in <module>
#       1 start=time.time()
#       2 for id in ids['id']:
# ----> 3     df.loc[len(df)]=get_row(id)
#       4 end=time.time()
#       5 print(end-start)
#
# <ipython-input-28-24b2084556c0> in get_row(id)
#       1 def get_row(id):
#       2     track=sp.track(id)
# ----> 3     features=sp.audio_features(id)
#       4
#       5     name = track['name']
#
# /opt/anaconda3/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#    1617         if isinstance(tracks, str):
#    1618             trackid = self._get_id("track", tracks)
# -> 1619             results = self._get("audio-features/?ids=" + trackid)
#    1620         else:
#    1621             tlist = [self._get_id("track", t) for t in tracks]
#
# ...

# %%
df
# Out:
#                            id  \
# 0      7CwboxAi6CvMcWrDfbxttR
# 1      691Wr3tOjDqic3OTPLouX3
# 2      1G4ldEIb2HXaLUsEu9lcHo
# 3      0fZXClbtHvHG0FDWpQy1wg
# 4      6YnnBx8Iq1XvlBrgonGLfP
# ...                       ...
# 33677  79tvx0aszVr5QPEWZt4agN
# 33678  0t1WvD3iIGsmMl9xLYvP6v
# 33679  1Bo5CD2Tg8di5QSJHEoHmZ
# 33680  5cvzazmKknWEYWG3taVUys
# 33681  6y2Z7nsLVkoe9yEonEXPQA
#
#                                                   name  \
# 0      Drink to That All Night (Remix) (feat. Pitbull)
# 1                                Ramblin' Gamblin' Man
# 2                                    Hold Your Head Up
# 3                                           Opalescent
# 4                                             Cable TV
# ...                                                ...
# 33677                    Vampire - Feat. Whiteboy John
# 33678                                      Les cadeaux
# 33679                                        La Diabla
# ...

# %%
len(ids)
# Out:
# 310032
